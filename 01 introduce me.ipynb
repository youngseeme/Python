# %%
type('string')
# Out:
# str

# %%
a = '박지음'

# %%
test = '안녕하세요 ' + a + '입니다. 반갑습니다.'

# %%
test
# Out:
# '안녕하세요 박지음입니다. 반갑습니다.'

# %%
def sqare(t):
    return t * t

# %%
def sqaure(t):
    return t * t
x = int(input("신장: "))
y = int(input("체중: "))
meter = x * 0.01
print("BMI: ", y / sqaure(meter))
# Out:
# 신장:  160
# 체중:  50
# BMI:  19.531249999999996
